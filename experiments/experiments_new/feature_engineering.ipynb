# %%
import missingno as msno
import pandas as pd
import os
print(os.getcwd())
os.chdir('d:\\vscode_machineLearning\\BEST_PROJECTS\\ForbesBillionaires')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\experiments_new
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires

# %%
df = pd.read_csv(r'artifacts/cleand_data/billionaires.csv')

# %%
df = pd.read_csv(r'artifacts/ForbesBillionaires-dataset/billionaires_2023.csv')

# %%
df
# Out:
#       year  month  rank net_worth  last_name first_name  \
# 0     2023      4     1   211.0 B    Arnault    Bernard
# 1     2023      4     2   180.0 B       Musk       Elon
# 2     2023      4     3   114.0 B      Bezos       Jeff
# 3     2023      4     4   107.0 B    Ellison      Larry
# 4     2023      4     5   106.0 B    Buffett     Warren
# ...    ...    ...   ...       ...        ...        ...
# 2635  2023      4  2540     1.0 B         Yu       Rong
# 2636  2023      4  2540     1.0 B  Yuengling    Richard
# 2637  2023      4  2540     1.0 B      Zhang    Gongyun
# 2638  2023      4  2540     1.0 B      Zhang    Guiping
# 2639  2023      4  2540     1.0 B      Zobel      Inigo
#
#                      full_name  birth_date   age gender  \
# 0     Bernard Arnault & family  1949-03-05  74.0   Male
# 1                    Elon Musk  1971-06-28  51.0   Male
# 2                   Jeff Bezos  1964-01-12  59.0   Male
# 3                Larry Ellison  1944-08-17  78.0   Male
# ...

# %% [markdown]
# ### To drop:
# - organization_name
# - position_in_organization

# %%
df = df.drop(columns=['organization_name','position_in_organization'])

# %% [markdown]
# ## droping these columns because they are same.
# - first name
# - last name
# - business_industries
# - country_of_residence

# %%
df = df.drop(columns=['last_name','first_name','business_industries'])

# %%
df = df.drop(columns=['country_of_residence'])

# %% [markdown]
# ## droping birth_date
# because I don't need

# %%
df = df.drop(columns=['birth_date'])

# %% [markdown]
# ## net_worth

# %%
def replace(val):
    return val.replace('B','')
df['net_worth'] = df['net_worth'].apply(func=replace)

# %%
df
# Out:
#       year  month  rank net_worth                 full_name   age gender  \
# 0     2023      4     1    211.0   Bernard Arnault & family  74.0   Male
# 1     2023      4     2    180.0                  Elon Musk  51.0   Male
# 2     2023      4     3    114.0                 Jeff Bezos  59.0   Male
# 3     2023      4     4    107.0              Larry Ellison  78.0   Male
# 4     2023      4     5    106.0             Warren Buffett  92.0   Male
# ...    ...    ...   ...       ...                       ...   ...    ...
# 2635  2023      4  2540      1.0                    Yu Rong  51.0   Male
# 2636  2023      4  2540      1.0     Richard Yuengling, Jr.  80.0   Male
# 2637  2023      4  2540      1.0              Zhang Gongyun  60.0   Male
# 2638  2023      4  2540      1.0     Zhang Guiping & family  71.0   Male
# 2639  2023      4  2540      1.0                Inigo Zobel  66.0   Male
#
#      country_of_citizenship city_of_residence      business_category  \
# ...

# %% [markdown]
# ## I have 2023 year only so I will drop.

# %%
df = df.drop(columns='year')

# %%
df
# Out:
#       month  rank net_worth                 full_name   age gender  \
# 0         4     1    211.0   Bernard Arnault & family  74.0   Male
# 1         4     2    180.0                  Elon Musk  51.0   Male
# 2         4     3    114.0                 Jeff Bezos  59.0   Male
# 3         4     4    107.0              Larry Ellison  78.0   Male
# 4         4     5    106.0             Warren Buffett  92.0   Male
# ...     ...   ...       ...                       ...   ...    ...
# 2635      4  2540      1.0                    Yu Rong  51.0   Male
# 2636      4  2540      1.0     Richard Yuengling, Jr.  80.0   Male
# 2637      4  2540      1.0              Zhang Gongyun  60.0   Male
# 2638      4  2540      1.0     Zhang Guiping & family  71.0   Male
# 2639      4  2540      1.0                Inigo Zobel  66.0   Male
#
#      country_of_citizenship city_of_residence      business_category  \
# 0                    France             Paris       Fashion & Retail
# ...

# %% [markdown]
# ## I have 4 month only so I will drop.

# %%
df['month'].value_counts()
# Out:
# month
# 4    2640
# Name: count, dtype: int64

# %%
df = df.drop(columns='month')

# %%
df
# Out:
#       rank net_worth                 full_name   age gender  \
# 0        1    211.0   Bernard Arnault & family  74.0   Male
# 1        2    180.0                  Elon Musk  51.0   Male
# 2        3    114.0                 Jeff Bezos  59.0   Male
# 3        4    107.0              Larry Ellison  78.0   Male
# 4        5    106.0             Warren Buffett  92.0   Male
# ...    ...       ...                       ...   ...    ...
# 2635  2540      1.0                    Yu Rong  51.0   Male
# 2636  2540      1.0     Richard Yuengling, Jr.  80.0   Male
# 2637  2540      1.0              Zhang Gongyun  60.0   Male
# 2638  2540      1.0     Zhang Guiping & family  71.0   Male
# 2639  2540      1.0                Inigo Zobel  66.0   Male
#
#      country_of_citizenship city_of_residence      business_category  \
# 0                    France             Paris       Fashion & Retail
# 1             United States            Austin             Automotive
# ...

# %%
df['rank'].value_counts()
# Out:
# rank
# 2259    146
# 2405    135
# 2133    126
# 1905    115
# 2020    113
#        ...
# 93        1
# 99        1
# 100       1
# 103       1
# 1         1
# Name: count, Length: 219, dtype: int64

# %%
df.tail()
# Out:
#       rank net_worth               full_name   age gender  \
# 2635  2540      1.0                  Yu Rong  51.0   Male
# 2636  2540      1.0   Richard Yuengling, Jr.  80.0   Male
# 2637  2540      1.0            Zhang Gongyun  60.0   Male
# 2638  2540      1.0   Zhang Guiping & family  71.0   Male
# 2639  2540      1.0              Inigo Zobel  66.0   Male
#
#      country_of_citizenship city_of_residence business_category  self_made  \
# 2635                  China          Shanghai        Healthcare       True
# 2636          United States        Pottsville   Food & Beverage      False
# 2637                  China             Gaomi     Manufacturing       True
# 2638                  China           Nanjing       Real Estate       True
# 2639            Philippines            Makati       Diversified      False
#
#          wealth_status
# 2635         Decreased
# 2636     Remained Even
# 2637  Returned to List
# 2638         Decreased
# 2639  Returned to List

# %% [markdown]
# ## net_worth

# %%
# def round_col(num):
#     return round(num)
df['net_worth'] = df['net_worth'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\experiments_new\feature_engineering.ipynb Cell 25 line 3
#       <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbesBillionaires/experiments_new/feature_engineering.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> # def round_col(num):
#       <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbesBillionaires/experiments_new/feature_engineering.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> #     return round(num)
# ----> <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbesBillionaires/experiments_new/feature_engineering.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> df['net_worth'] = df['net_worth'].astype(int)
#
# ...

# %%
df[df['net_worth'] == '211.0 '].index
# Out:
# Index([0], dtype='int64')

# %%
df['net_worth'][df[df['net_worth'] == '211.0 '].index] = int(211.0)
# Out:
# C:\Users\Gyanprakash\AppData\Local\Temp\ipykernel_11512\134427072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['net_worth'][df[df['net_worth'] == '211.0 '].index] = int(211.0)

# %%
df[df['net_worth'] == '211.0 ']['net_worth']
# Out:
# Series([], Name: net_worth, dtype: object)

# %%
df['net_worth'] = df['net_worth'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\experiments_new\feature_engineering.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbesBillionaires/experiments_new/feature_engineering.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df['net_worth'] = df['net_worth'].astype(int)
#
# File d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\forbesvenv\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
df['net_worth'] = df['net_worth'].astype('float64')

# %%
df['net_worth'] = df['net_worth'].replace('.', '').astype('int64')

# %%
df
# Out:
#       rank  net_worth                 full_name   age gender  \
# 0        1        211  Bernard Arnault & family  74.0   Male
# 1        2        180                 Elon Musk  51.0   Male
# 2        3        114                Jeff Bezos  59.0   Male
# 3        4        107             Larry Ellison  78.0   Male
# 4        5        106            Warren Buffett  92.0   Male
# ...    ...        ...                       ...   ...    ...
# 2635  2540          1                   Yu Rong  51.0   Male
# 2636  2540          1    Richard Yuengling, Jr.  80.0   Male
# 2637  2540          1             Zhang Gongyun  60.0   Male
# 2638  2540          1    Zhang Guiping & family  71.0   Male
# 2639  2540          1               Inigo Zobel  66.0   Male
#
#      country_of_citizenship city_of_residence      business_category  \
# 0                    France             Paris       Fashion & Retail
# 1             United States            Austin             Automotive
# ...

# %%
df.dtypes
# Out:
# rank                        int64
# net_worth                   int64
# full_name                  object
# age                       float64
# gender                     object
# country_of_citizenship     object
# city_of_residence          object
# business_category          object
# self_made                    bool
# wealth_status              object
# dtype: object

# %% [markdown]
# ## age

# %%
df.isnull().sum()
# Out:
# rank                        0
# net_worth                   0
# full_name                   0
# age                        65
# gender                      0
# country_of_citizenship      0
# city_of_residence          72
# business_category           0
# self_made                   0
# wealth_status             229
# dtype: int64

# %%
df['age'].dropna(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df['age'] = df['age'].astype('int64')

# %%
print(df.dtypes)
print(df.isnull().sum())
# Out:
# rank                       int64
# net_worth                  int64
# full_name                 object
# age                        int64
# gender                    object
# country_of_citizenship    object
# city_of_residence         object
# business_category         object
# self_made                   bool
# wealth_status             object
# dtype: object
# rank                      0
# net_worth                 0
# full_name                 0
# age                       0
# gender                    0
# country_of_citizenship    0
# city_of_residence         0
# business_category         0
# self_made                 0
# wealth_status             0
# dtype: int64

# %%
df.shape
# Out:
# (2338, 10)

# %%
df
# Out:
#       rank  net_worth                 full_name  age gender  \
# 0        1        211  Bernard Arnault & family   74   Male
# 1        2        180                 Elon Musk   51   Male
# 2        3        114                Jeff Bezos   59   Male
# 3        4        107             Larry Ellison   78   Male
# 4        5        106            Warren Buffett   92   Male
# ...    ...        ...                       ...  ...    ...
# 2635  2540          1                   Yu Rong   51   Male
# 2636  2540          1    Richard Yuengling, Jr.   80   Male
# 2637  2540          1             Zhang Gongyun   60   Male
# 2638  2540          1    Zhang Guiping & family   71   Male
# 2639  2540          1               Inigo Zobel   66   Male
#
#      country_of_citizenship city_of_residence      business_category  \
# 0                    France             Paris       Fashion & Retail
# 1             United States            Austin             Automotive
# ...

# %%
df.to_csv(r'artifacts/cleand_data/not_encoded_data.csv',index=False)
