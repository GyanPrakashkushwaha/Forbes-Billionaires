# %%
import os
print(os.getcwd())
os.chdir("d:/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires")
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\experiments\code_trail
# d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires

# %% [markdown]
# ## Entity

# %%
from pathlib import Path
from dataclasses import dataclass

# %%
@dataclass(frozen=True)
class DataValidationConfig:
    root_dir:Path
    STATUS_file :str
    data_dir:Path
    schema_check:dict

# %% [markdown]
# ## configuration manager

# %%
from predictor.constatns import *
from predictor.utils import *

# %%
CONFIG_FILE_PATH
# Out:
# WindowsPath('config/config.yaml')

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH):


        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_dirs([self.config.artifacts_root])

    
    def get_data_validation_config(self) -> DataValidationConfig:
        config = self.config.data_validation
        schema = self.schema.INDEPENDENT_FEATURES

        create_dirs([config.root_dir])
        

        data_validation_config =  DataValidationConfig(
            root_dir=config.root_dir,
            STATUS_file=config.STATUS_FILE,
            data_dir=config.data_dir,
            schema_check=schema
        )

        return data_validation_config

# %% [markdown]
# ## components

# %%
from predictor import logger
import pandas as pd

# %%
config = read_yaml(CONFIG_FILE_PATH)
# Out:
# [2023-09-13 11:15:07,416: INFO: utils: yaml file: config\config.yaml loaded successfully]

# %%
type(config)
# Out:
# box.config_box.ConfigBox

# %%
config.artifacts_root
# Out:
# 'artifacts'

# %%
config.data_validation.data_dir
# Out:
# 'artifacts\\cleand_data\\billionaires.csv'

# %%
pd.read_csv(config.data_validation.data_dir)
# Out:
#        year  month  rank  net_worth               full_name   age gender  \
# 0      2017      3     1       86.0              Bill Gates  61.0   Male
# 1      2017      3     2       75.6          Warren Buffett  86.0   Male
# 2      2017      3     3       72.8              Jeff Bezos  53.0   Male
# 3      2017      3     4       71.3          Amancio Ortega  80.0   Male
# 4      2017      3     5       56.0         Mark Zuckerberg  32.0   Male
# ...     ...    ...   ...        ...                     ...   ...    ...
# 16557  2023      4  2540        1.0                 Yu Rong  51.0   Male
# 16558  2023      4  2540        1.0  Richard Yuengling, Jr.  80.0   Male
# 16559  2023      4  2540        1.0           Zhang Gongyun  60.0   Male
# 16560  2023      4  2540        1.0  Zhang Guiping & family  71.0   Male
# 16561  2023      4  2540        1.0             Inigo Zobel  66.0   Male
#
#       country_of_citizenship city_of_residence        business_category  \
# 0              United States            Medina               Technology
# 1              United States             Omaha  Finance and Investments
# 2              United States           Seattle               Technology
# 3                      Spain         La Coruna         Fashion & Retail
# 4              United States         Palo Alto               Technology
# ...                      ...               ...                      ...
# 16557                  China          Shanghai               Healthcare
# 16558          United States        Pottsville          Food & Beverage
# 16559                  China             Gaomi            Manufacturing
# 16560                  China           Nanjing              Real Estate
# 16561            Philippines            Makati              Diversified
#
#        self_made     wealth_status
# 0           True         Increased
# 1           True         Increased
# 2           True         Increased
# 3           True         Increased
# 4           True         Increased
# ...          ...               ...
# 16557       True         Decreased
# 16558      False     Remained Even
# 16559       True  Returned to List
# 16560       True         Decreased
# 16561      False  Returned to List
#
# [16562 rows x 12 columns]

# %%
class DataValidataion:
    def __init__(self,config_in :DataValidationConfig):
        self.config_in = config_in
    
    def validate_features(self) -> bool:
        try:
            validation_status = False
            df = pd.read_csv(self.config_in.data_dir)
            all_features = list(df.columns)
            all_schema = self.config_in.schema_check

            for cols in all_features:
                if cols not in all_schema:
                    validation_status = False
                    with open(self.config_in.STATUS_file,'w') as stat_file:
                        stat_file.write(f"Validation status: {validation_status}")
                
                else:
                    validation_status = True
                    with open(self.config_in.STATUS_file,'w') as f:
                        f.write(f"Validation status: {validation_status}")

            return validation_status
        except Exception as e:
            raise CustomException(e)

# %% [markdown]
# ## pipeline

# %%
# try:
#     confg = ConfigurationManager()
#     data_val_confg = config.get_data_validation_config()
#     data_validation = DataValidataion(config_in=data_val_confg)
#     data_validation.validate_features()

# except Exception as e:
#     raise CustomException(e,sys)


try:
    config = ConfigurationManager()
    data_val_config = config.get_data_validation_config()
    data_validation = DataValidation(config_in=data_val_config)
    data_validation.validate_features()
except Exception as e:
    raise CustomException(e,sys)
# Out:
# [2023-09-13 11:15:10,695: INFO: utils: yaml file: config\config.yaml loaded successfully]
# [2023-09-13 11:15:10,696: INFO: utils: yaml file: params.yaml loaded successfully]
# ---------------------------------------------------------------------------
#
# BoxValueError                             Traceback (most recent call last)
#
# File d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\predictor\utils.py:18, in read_yaml(path_to_yaml)
#
#      17         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
#
# ---> 18         return ConfigBox(content)
#
#      19 except Exception as e:
#
#
#
# File d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\forbesvenv\Lib\site-packages\box\box.py:259, in Box.__init__(self, default_box, default_box_attr, default_box_none_transform, default_box_create_on_get, frozen_box, camel_killer_box, conversion_box, modify_tuples_box, box_safe_prefix, box_duplicates, box_intact_types, box_recast, box_dots, box_class, *args, **kwargs)
#
#     258     else:
#
# --> 259         raise BoxValueError("First argument must be mapping or iterable")
#
#     260 elif args:
#
#
#
# BoxValueError: First argument must be mapping or iterable
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# CustomException                           Traceback (most recent call last)
#
# d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\experiments\code_trail\01_validation.ipynb Cell 18 line 1
#
#      <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a> try:
#
# ---> <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=11'>12</a>     config = ConfigurationManager()
#
#      <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a>     data_val_config = config.get_data_validation_config()
#
#
#
# d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\experiments\code_trail\01_validation.ipynb Cell 18 line 1
#
#       <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=8'>9</a> self.config = read_yaml(config_filepath)
#
# ---> <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a> self.params = read_yaml(params_filepath)
#
#      <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a> self.schema = read_yaml(schema_filepath)
#
#
#
# File d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\forbesvenv\Lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#
#     845         raise EnsureError(msg.format(
#
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#
#     847         ))
#
# --> 849 return_val = self.f(*args, **kwargs)
#
#     850 if not isinstance(return_val, self.return_templ):
#
#
#
# File d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\predictor\utils.py:20, in read_yaml(path_to_yaml)
#
#      19 except Exception as e:
#
# ---> 20     raise CustomException(error_msg=e, error_detail=sys)
#
#
#
# CustomException: Error occured in python script name [d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\predictor\utils.py] line number [18] error message [First argument must be mapping or iterable]
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# CustomException                           Traceback (most recent call last)
#
# d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\experiments\code_trail\01_validation.ipynb Cell 18 line 1
#
#      <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a>     data_validation.validate_features()
#
#      <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=15'>16</a> except Exception as e:
#
# ---> <a href='vscode-notebook-cell:/d%3A/vscode_machineLearning/BEST_PROJECTS/ForbsBillionaires/experiments/code_trail/01_validation.ipynb#X23sZmlsZQ%3D%3D?line=16'>17</a>     raise CustomException(e,sys)
#
#
#
# CustomException: Error occured in python script name [C:\Users\Gyanprakash\AppData\Local\Temp\ipykernel_16080\2040550444.py] line number [12] error message [Error occured in python script name [d:\vscode_machineLearning\BEST_PROJECTS\ForbsBillionaires\predictor\utils.py] line number [18] error message [First argument must be mapping or iterable]]
