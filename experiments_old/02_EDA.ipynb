# %%
import missingno as msno
import pandas as pd
import os
print(os.getcwd())
os.chdir('d:\\vscode_machineLearning\\BEST_PROJECTS\\ForbesBillionaires')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\experiments
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'artifacts/ForbesBillionaires-dataset/all_billionaires_1997_2023.csv')

# %%
df.sample(20)
# Out:
#        year  month    rank net_worth   last_name     first_name  \
# 12501  2015      3   949.0     2.0 B       Karim       Bachtiar
# 24145  2021      4   476.0     5.8 B        Chan          Laiwa
# 6384   2011      3   347.0     3.2 B       Rales         Steven
# 9206   2013      3   736.0     2.0 B    Benetton        Luciano
# 20316  2019      3   877.0     2.6 B       Lohia          Aloke
# 868    2003      3   236.0     1.7 B    Huizenga       H. Wayne
# 23301  2020      4  1613.0     1.3 B         Zhu         Yiming
# 30260  2023      4  1164.0     2.6 B     Batista         Wesley
# 11048  2014      3  1154.0     1.5 B        Chen       Yung-Tai
# 16930  2017      3  1678.0     1.2 B       Singh        Analjit
# 8226   2012      3   960.0     1.3 B        Herz       Ingeburg
# 13509  2016      3   151.0     7.6 B  Abramovich          Roman
# 20428  2019      3  1008.0     2.3 B     Andreev         Andrey
# 29776  2023      4   679.0     4.1 B  Garavoglia           Luca
# 29707  2023      4   611.0     4.5 B      Murthy  N.R. Narayana
# 31218  2023      4  2020.0     1.4 B       Zhang            Xin
# 31423  2023      4  2259.0     1.2 B     Michael        Jeffrey
# 1436   2004      3   552.0     1.0 B        Ford        William
# 17541  2018      3   321.0     5.6 B      LeFrak        Richard
# 3140   2007      3   618.0     1.6 B         NaN            NaN
#
#                       full_name  birth_date   age  gender  \
# 12501   Bachtiar Karim & family  1957-01-01  58.0    Male
# 24145       Chan Laiwa & family  1941-01-01  80.0  Female
# 6384               Steven Rales  1951-03-31  59.0    Male
# 9206           Luciano Benetton  1935-05-13  77.0    Male
# 20316               Aloke Lohia  1958-11-27  60.0    Male
# 868           H. Wayne Huizenga  1937-12-29  65.0    Male
# 23301                Zhu Yiming  1972-07-01  47.0    Male
# 30260            Wesley Batista  1972-12-08  50.0    Male
# 11048             Chen Yung-Tai  1936-01-01  78.0    Male
# 16930             Analjit Singh  1954-01-11  63.0    Male
# 8226              Ingeburg Herz  1922-01-01  90.0  Female
# 13509          Roman Abramovich  1966-10-24  49.0    Male
# 20428            Andrey Andreev  1974-02-03  45.0    Male
# 29776           Luca Garavoglia  1969-02-27  54.0    Male
# 29707      N.R. Narayana Murthy  1946-08-20  76.0    Male
# 31218                 Zhang Xin  1965-08-24  57.0  Female
# 31423  Jeffrey Michael & family  1956-07-18  66.0    Male
# 1436            William Ford Sr  1925-03-14  79.0    Male
# 17541   Richard LeFrak & family  1945-08-29  72.0    Male
# 3140           Kutayba Alghanim         NaN  60.0     NaN
#
#       country_of_citizenship country_of_residence     city_of_residence  \
# 12501              Indonesia            Indonesia                 Medan
# 24145                  China                China               Beijing
# 6384           United States        United States            Washington
# 9206                   Italy                Italy               Treviso
# 20316                  India             Thailand               Bangkok
# 868            United States        United States       Fort Lauderdale
# 23301                  China                China               Beijing
# 30260                 Brazil               Brazil             Sao Paulo
# 11048                 Taiwan               Taiwan                Taipei
# 16930                  India                India                 Delhi
# 8226                 Germany              Germany               Hamburg
# 13509                 Russia               Russia                Moscow
# 20428         United Kingdom       United Kingdom                London
# 29776                  Italy                Italy                 Milan
# 29707                  India                India             Bangalore
# 31218                  China                China               Beijing
# 31423          United States        United States            Minnetonka
# 1436           United States        United States  Grosse Pointe Shores
# 17541          United States        United States              New York
# 3140                  Kuwait               Kuwait           Kuwait City
#
#       business_category     business_industries organization_name  \
# 12501     Manufacturing       ['Manufacturing']               NaN
# 24145       Real Estate         ['Real Estate']               NaN
# 6384            Service             ['Service']           Danaher
# 9206   Fashion & Retail    ['Fashion & Retail']               NaN
# 20316     Manufacturing       ['Manufacturing']               NaN
# 868                 NaN         ['Investments']               NaN
# 23301        Technology          ['Technology']               NaN
# 30260   Food & Beverage     ['Food & Beverage']               NaN
# 11048       Real Estate         ['Real Estate']               NaN
# 16930        Healthcare          ['Healthcare']               NaN
# 8226                NaN  ['Fashion and Retail']               NaN
# 13509       Diversified         ['Diversified']               NaN
# 20428        Technology          ['Technology']               NaN
# 29776   Food & Beverage     ['Food & Beverage']               NaN
# 29707        Technology          ['Technology']               NaN
# 31218       Real Estate         ['Real Estate']        SOHO China
# 31423        Technology          ['Technology']               NaN
# 1436                NaN       ['Manufacturing']               NaN
# 17541       Real Estate         ['Real Estate']               NaN
# 3140                NaN                     NaN               NaN
#
#       position_in_organization self_made     wealth_status
# 12501                      NaN     False     Remained Even
# 24145           Philanthropist      True     Remained Even
# 6384                  Chairman      True         Increased
# 9206              Entrepreneur      True         Decreased
# 20316                      NaN     False         Decreased
# 868                        NaN     False         Decreased
# 23301                      NaN      True               NaN
# 30260                      NaN     False         Decreased
# 11048                      NaN      True         Increased
# 16930                      NaN     False               NaN
# 8226                       NaN     False         Increased
# 13509                      NaN      True         Decreased
# 20428                      NaN      True         Increased
# 29776                      NaN     False         Increased
# 29707                      NaN      True         Increased
# 31218           Cofounder, CEO      True               NaN
# 31423                      NaN      True         Increased
# 1436                       NaN     False  Returned to List
# 17541                      NaN     False         Decreased
# 3140                       NaN       NaN               NaN

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df['net_worth'] = df['net_worth'].str.replace('B','').str.strip().astype(float)
df['birth_date'] = pd.to_datetime(df['birth_date'])
df['birth_date_month'] = df['birth_date'].dt.month
df['birth_date_year'] = df['birth_date'].dt.year
df['birth_date_month_name'] = df['birth_date'].dt.strftime('%B')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31732 entries, 0 to 31731
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      31732 non-null  int64
#  1   month                     31732 non-null  int64
#  2   rank                      31714 non-null  float64
#  3   net_worth                 31732 non-null  float64
#  4   last_name                 28043 non-null  object
#  5   first_name                27985 non-null  object
#  6   full_name                 31732 non-null  object
#  7   birth_date                27328 non-null  datetime64[ns]
#  8   age                       31057 non-null  float64
#  9   gender                    27903 non-null  object
#  10  country_of_citizenship    31723 non-null  object
#  11  country_of_residence      31030 non-null  object
#  12  city_of_residence         30797 non-null  object
#  13  business_category         25889 non-null  object
#  14  business_industries       30742 non-null  object
#  15  organization_name         4388 non-null   object
#  16  position_in_organization  4692 non-null   object
#  17  self_made                 28043 non-null  object
#  18  wealth_status             24586 non-null  object
#  19  birth_date_month          27328 non-null  float64
#  20  birth_date_year           27328 non-null  float64
#  21  birth_date_month_name     27328 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(14)
# memory usage: 5.3+ MB

# %% [markdown]
# ## Month does not affect net worth.

# %%
sns.lmplot(data = df, x='net_worth', y='birth_date_month', line_kws={'color': 'red'})
plt.grid(True)
plt.title('birth_date_month and net_worth correlation')
plt.show()
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\forbesvenv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10,6))
sns.lmplot(data = df, x='net_worth', y='age', line_kws={'color': 'red'})
# plt.grid(True)
plt.title('age and net_worth correlation')
plt.show()
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\forbesvenv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data = df, x='net_worth', y='age', hue='gender')
plt.grid(True)
plt.title('age and net_worth correlation by gender')
plt.show()
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\ForbesBillionaires\forbesvenv\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df[df['age'] > 0].sort_values(by='age',ascending=True)
# Out:
#        year  month    rank  net_worth    last_name   first_name  \
# 24609  2021      4   925.0        3.3      Lehmann  Kevin David
# 595    2002      3   327.0        1.4          NaN          NaN
# 29915  2023      4   818.0        3.5  Del Vecchio     Clemente
# 30847  2023      4  1725.0        1.7          Kim    Jung-youn
# 14839  2016      3  1476.0        1.2     Andresen    Alexandra
# ...     ...    ...     ...        ...          ...          ...
# 20540  2019      3  1116.0        2.1        Chang    Yun Chung
# 31272  2023      4  2133.0        1.3       Joseph       George
# 15767  2017      3   581.0        3.3  Rockefeller        David
# 23438  2020      4  1851.0        1.1        Chang    Yun Chung
# 7486   2012      3   248.0        4.3      Haefner       Walter
#
#                         full_name birth_date    age  gender  ...  \
# 24609         Kevin David Lehmann 2002-09-01   18.0    Male  ...
# 595    Albert von Thurn und Taxis        NaT   18.0     NaN  ...
# 29915        Clemente Del Vecchio 2004-05-06   18.0    Male  ...
# 30847               Kim Jung-youn 2004-01-01   19.0  Female  ...
# 14839          Alexandra Andresen 1996-07-23   19.0  Female  ...
# ...                           ...        ...    ...     ...  ...
# 20540             Chang Yun Chung 1918-08-27  100.0    Male  ...
# 31272               George Joseph 1921-09-11  101.0    Male  ...
# 15767      David Rockefeller, Sr. 1915-06-12  101.0    Male  ...
# 23438             Chang Yun Chung 1918-08-27  101.0    Male  ...
# 7486               Walter Haefner 1910-09-13  101.0    Male  ...
#
#       city_of_residence        business_category          business_industries  \
# 24609               NaN         Fashion & Retail         ['Fashion & Retail']
# 595          Regensburg                      NaN                          NaN
# 29915             Milan         Fashion & Retail         ['Fashion & Retail']
# 30847               NaN    Media & Entertainment    ['Media & Entertainment']
# 14839              Oslo              Diversified              ['Diversified']
# ...                 ...                      ...                          ...
# 20540         Singapore                Logistics                ['Logistics']
# 31272       Los Angeles    Finance & Investments    ['Finance & Investments']
# 15767               NaN  Finance and Investments  ['Finance and Investments']
# 23438         Singapore                Logistics                ['Logistics']
# 7486                NaN               Technology               ['Technology']
#
#       organization_name position_in_organization self_made wealth_status  \
# 24609               NaN                      NaN     False           NaN
# 595                 NaN                      NaN       NaN           NaN
# 29915               NaN                      NaN     False           NaN
# 30847               NaN                      NaN     False           NaN
# 14839               NaN                      NaN     False           NaN
# ...                 ...                      ...       ...           ...
# 20540               NaN                      NaN      True     Increased
# 31272               NaN                      NaN      True     Decreased
# 15767               NaN           Philanthropist     False     Increased
# 23438               NaN                      NaN      True     Decreased
# 7486                NaN                      NaN      True     Increased
#
#       birth_date_month birth_date_year  birth_date_month_name
# 24609              9.0          2002.0              September
# 595                NaN             NaN                    NaN
# 29915              5.0          2004.0                    May
# 30847              1.0          2004.0                January
# 14839              7.0          1996.0                   July
# ...                ...             ...                    ...
# 20540              8.0          1918.0                 August
# 31272              9.0          1921.0              September
# 15767              6.0          1915.0                   June
# 23438              8.0          1918.0                 August
# 7486               9.0          1910.0              September
#
# [30849 rows x 22 columns]

# %%
filtered_df = df[df['age'] > 0].sort_values('age', ascending=True)

plt.figure(figsize=(12, 6))
sns.lineplot(x='age', y='net_worth', hue='gender', data=filtered_df, palette={'Male': 'blue', 'Female': 'red'})

plt.title('Net Worth vs. Age')
plt.xlabel('Age')
plt.ylabel('Net Worth')
plt.legend()
plt.grid(True)
plt.show()

# %%
top_categories = df['business_category'].value_counts().head(5)
top_countries = df['country_of_residence'].value_counts().head(5)
top_positions = df['position_in_organization'].value_counts().head(5)

sns.set(style="whitegrid")


fig, axes = plt.subplots(3, 1, figsize=(10, 8), sharex=True)


sns.barplot(ax=axes[0], x=top_categories.values, y=top_categories.index, palette="viridis")
axes[0].set_title('Top 5 Business Categories')
axes[0].set_xlabel('Count')
axes[0].set_ylabel('Business Category')

sns.barplot(ax=axes[1], x=top_countries.values, y=top_countries.index, palette="viridis")
axes[1].set_title('Top 5 Business Countries')
axes[1].set_xlabel('Count')
axes[1].set_ylabel('Business Country')

sns.barplot(ax=axes[2], x=top_positions.values, y=top_positions.index, palette="viridis")
axes[2].set_title('Top 5 Business Positions')
axes[2].set_xlabel('Count')
axes[2].set_ylabel('Business Positions')

plt.tight_layout()

plt.show()

# %%
df['year'].value_counts()
# Out:
# year
# 2021    2755
# 2022    2668
# 2023    2640
# 2018    2208
# 2019    2153
# 2020    2095
# 2017    2043
# 2015    1826
# 2016    1811
# 2014    1645
# 2013    1426
# 2012    1226
# 2011    1209
# 2010    1011
# 2008     908
# 2007     761
# 2009     738
# 2006     628
# 2005     530
# 2004     432
# 2001     335
# 2002     333
# 2003     332
# 2000       8
# 1999       8
# 1997       2
# 1998       1
# Name: count, dtype: int64

# %%
df.groupby('year').head()
# Out:
#        year  month  rank  net_worth     last_name            first_name  \
# 0      1997      7   NaN        2.0  Sophonpanich                Chatri
# 1      1997      7   NaN        1.8     Adulyadej         King Bhumibol
# 2      1998      7   NaN        3.3         Safra                Edmond
# 3      1999      7   NaN        1.0       Hinduja  Srichand, Gopichand,
# 4      1999      7   NaN        7.1       Schwarz                Dieter
# ...     ...    ...   ...        ...           ...                   ...
# 29092  2023      4   1.0      211.0       Arnault               Bernard
# 29093  2023      4   2.0      180.0          Musk                  Elon
# 29094  2023      4   3.0      114.0         Bezos                  Jeff
# 29095  2023      4   4.0      107.0       Ellison                 Larry
# 29096  2023      4   5.0      106.0       Buffett                Warren
#
#                           full_name birth_date   age gender  ...  \
# 0      Chatri Sophonpanich & family 1934-02-28  73.0   Male  ...
# 1           King Bhumibol Adulyadej 1927-12-05  69.0   Male  ...
# 2                      Edmond Safra 1932-08-06  65.0   Male  ...
# 3      Srichand & Gopichand Hinduja 1935-11-28   NaN    NaN  ...
# 4                    Dieter Schwarz 1939-09-24  59.0   Male  ...
# ...                             ...        ...   ...    ...  ...
# 29092      Bernard Arnault & family 1949-03-05  74.0   Male  ...
# 29093                     Elon Musk 1971-06-28  51.0   Male  ...
# 29094                    Jeff Bezos 1964-01-12  59.0   Male  ...
# 29095                 Larry Ellison 1944-08-17  78.0   Male  ...
# 29096                Warren Buffett 1930-08-30  92.0   Male  ...
#
#       city_of_residence        business_category          business_industries  \
# 0               Bangkok  Finance and Investments  ['Finance and Investments']
# 1                   NaN                      NaN                          NaN
# 2                   NaN                      NaN                          NaN
# 3                London                      NaN                          NaN
# 4            Neckarsulm         Fashion & Retail         ['Fashion & Retail']
# ...                 ...                      ...                          ...
# 29092             Paris         Fashion & Retail         ['Fashion & Retail']
# 29093            Austin               Automotive               ['Automotive']
# 29094            Medina               Technology               ['Technology']
# 29095             Lanai               Technology               ['Technology']
# 29096             Omaha    Finance & Investments    ['Finance & Investments']
#
#                       organization_name position_in_organization self_made  \
# 0                                   NaN                      NaN     False
# 1                                   NaN                      NaN     False
# 2                                   NaN                      NaN      True
# 3                                   NaN                      NaN     False
# 4                                   NaN                      NaN      True
# ...                                 ...                      ...       ...
# 29092  LVMH Moët Hennessy Louis Vuitton         Chairman and CEO     False
# 29093                             Tesla                      CEO      True
# 29094                            Amazon     Chairman and Founder      True
# 29095                            Oracle          CTO and Founder      True
# 29096    Berkshire Hathaway Inc. (Cl A)                      CEO      True
#
#       wealth_status birth_date_month birth_date_year  birth_date_month_name
# 0               NaN              2.0          1934.0               February
# 1               NaN             12.0          1927.0               December
# 2               NaN              8.0          1932.0                 August
# 3               NaN             11.0          1935.0               November
# 4               NaN              9.0          1939.0              September
# ...             ...              ...             ...                    ...
# 29092     Increased              3.0          1949.0                  March
# 29093     Decreased              6.0          1971.0                   June
# 29094     Decreased              1.0          1964.0                January
# 29095     Increased              8.0          1944.0                 August
# 29096     Decreased              8.0          1930.0                 August
#
# [128 rows x 22 columns]

# %%
#dataset.sort_values(by='net_worth',ascending=False,inplace=True)
groupby_obj = df.groupby('year').head(1)[['year','first_name','net_worth']].sort_values(by='year')
#groupby_obj['net_worth'] = groupby_obj['net_worth'].str.replace('B',"").astype(float)
fig= plt.figure(figsize=(20,5))
ax = sns.barplot(data=groupby_obj,x='year',y='net_worth',width=0.2)
ax.bar_label(ax.containers[0],groupby_obj['first_name'], fmt='%.1f')
plt.title("Forbes Billionaires Evolution")
plt.show()

# %%
import plotly.express as px

# %%
df['rank'].value_counts()
# Out:
# rank
# 1818.0    234
# 1415.0    183
# 1513.0    166
# 2524.0    150
# 1929.0    147
#          ...
# 781.0       1
# 526.0       1
# 1152.0      1
# 1711.0      1
# 0.0         1
# Name: count, Length: 840, dtype: int64

# %% [markdown]
# 1. `import plotly.express as px`: This imports the Plotly Express library, often abbreviated as `px`, which provides a simplified interface for creating interactive visualizations.
#
# 2. `fig = px.bar(...)`: This line creates a bar chart using Plotly Express. The data for the chart is derived from a DataFrame called `df`.
#
#    - `df.groupby('year').head(10)`: This groups the DataFrame `df` by the 'year' column and then selects the top 10 rows within each group. This implies that the DataFrame contains information about billionaires over different years.
#
#    - `x='net_worth'`: The 'net_worth' column is used for the x-axis (horizontal axis) of the bar chart. It represents the net worth of the billionaires.
#
#    - `y='rank'`: The 'rank' column is used for the y-axis (vertical axis) of the bar chart. It represents the ranking of the billionaires.
#
#    - `range_x=[1, 230]`: This sets the range of the x-axis from 1 to 230.
#
#    - `range_y=[0, 12]`: This sets the range of the y-axis from 0 to 12.
#
#    - `orientation='h'`: This specifies that the bars should be horizontally oriented.
#
#    - `animation_frame="year"`: This creates an animation by showing the data for each year in a sequence.
#
#    - `text=df.groupby('year').head(10)['full_name']`: The 'full_name' column is used to provide text labels for each bar.
#
# 3. `fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 500`: This line sets the duration (in milliseconds) for each frame in the animation.
#
# 4. `fig.update_layout(...)`: This updates the layout of the chart with various settings:
#
#    - `title="Top 10 Forbes Billionaires Over Years"`: Sets the title of the chart.
#
#    - `height=500, width=1000`: Sets the height and width of the chart.
#
#    - `margin={"r": 0, "t": 50, "l": 0, "b": 0}`: Sets the margins around the chart area, with different values for the right, top, left, and bottom sides.
#
# 5. `fig.update_yaxes(autorange="reversed")`: This reverses the y-axis to have the highest rank at the top of the chart.
#
# 6. `fig.show()`: This line displays the animated bar chart in the output. It's important to note that this line is required to actually visualize the chart.

# %%
fig = px.bar(df.groupby('year').head(10),x='net_worth',y='rank', range_x=[1,230],range_y=[0,12],orientation='h',animation_frame="year",text=df.groupby('year').head(10)['full_name'])
fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 500
fig.update_layout(title="Top 10 Forbes Billionaires Over Years",height=500,width=1000, margin={"r":0,"t":50,"l":0,"b":0})
#fig.update_yaxes(visible=False, showticklabels=False)
fig.update_yaxes(autorange="reversed")
fig.show()

# %%
df
# Out:
#        year  month    rank  net_worth     last_name            first_name  \
# 0      1997      7     NaN        2.0  Sophonpanich                Chatri
# 1      1997      7     NaN        1.8     Adulyadej         King Bhumibol
# 2      1998      7     NaN        3.3         Safra                Edmond
# 3      1999      7     NaN        1.0       Hinduja  Srichand, Gopichand,
# 4      1999      7     NaN        7.1       Schwarz                Dieter
# ...     ...    ...     ...        ...           ...                   ...
# 31727  2023      4  2540.0        1.0            Yu                  Rong
# 31728  2023      4  2540.0        1.0     Yuengling               Richard
# 31729  2023      4  2540.0        1.0         Zhang               Gongyun
# 31730  2023      4  2540.0        1.0         Zhang               Guiping
# 31731  2023      4  2540.0        1.0         Zobel                 Inigo
#
#                           full_name birth_date   age gender  ...  \
# 0      Chatri Sophonpanich & family 1934-02-28  73.0   Male  ...
# 1           King Bhumibol Adulyadej 1927-12-05  69.0   Male  ...
# 2                      Edmond Safra 1932-08-06  65.0   Male  ...
# 3      Srichand & Gopichand Hinduja 1935-11-28   NaN    NaN  ...
# 4                    Dieter Schwarz 1939-09-24  59.0   Male  ...
# ...                             ...        ...   ...    ...  ...
# 31727                       Yu Rong 1971-12-14  51.0   Male  ...
# 31728        Richard Yuengling, Jr. 1943-03-10  80.0   Male  ...
# 31729                 Zhang Gongyun 1962-12-18  60.0   Male  ...
# 31730        Zhang Guiping & family 1951-08-21  71.0   Male  ...
# 31731                   Inigo Zobel 1956-11-01  66.0   Male  ...
#
#       city_of_residence        business_category          business_industries  \
# 0               Bangkok  Finance and Investments  ['Finance and Investments']
# 1                   NaN                      NaN                          NaN
# 2                   NaN                      NaN                          NaN
# 3                London                      NaN                          NaN
# 4            Neckarsulm         Fashion & Retail         ['Fashion & Retail']
# ...                 ...                      ...                          ...
# 31727          Shanghai               Healthcare               ['Healthcare']
# 31728        Pottsville          Food & Beverage          ['Food & Beverage']
# 31729             Gaomi            Manufacturing            ['Manufacturing']
# 31730           Nanjing              Real Estate              ['Real Estate']
# 31731            Makati              Diversified              ['Diversified']
#
#       organization_name position_in_organization self_made     wealth_status  \
# 0                   NaN                      NaN     False               NaN
# 1                   NaN                      NaN     False               NaN
# 2                   NaN                      NaN      True               NaN
# 3                   NaN                      NaN     False               NaN
# 4                   NaN                      NaN      True               NaN
# ...                 ...                      ...       ...               ...
# 31727               NaN                      NaN      True         Decreased
# 31728               NaN                      NaN     False     Remained Even
# 31729               NaN                      NaN      True  Returned to List
# 31730               NaN                      NaN      True         Decreased
# 31731               NaN                      NaN     False  Returned to List
#
#       birth_date_month birth_date_year  birth_date_month_name
# 0                  2.0          1934.0               February
# 1                 12.0          1927.0               December
# 2                  8.0          1932.0                 August
# 3                 11.0          1935.0               November
# 4                  9.0          1939.0              September
# ...                ...             ...                    ...
# 31727             12.0          1971.0               December
# 31728              3.0          1943.0                  March
# 31729             12.0          1962.0               December
# 31730              8.0          1951.0                 August
# 31731             11.0          1956.0               November
#
# [31732 rows x 22 columns]

# %%
df["age-Cat"] =df["age"].apply(lambda x: f"{int(x/10)*10} - {(int(x/10)*10)+10}" if x>0  else x)

fig= plt.figure(figsize=(20,5))
ax = sns.countplot(data=df.sort_values(by='age'),x='age-Cat',hue='gender',width=0.2)
plt.title("Range of Billionaires Age")
plt.show()

# %%
df.columns
# Out:
# Index(['year', 'month', 'rank', 'net_worth', 'last_name', 'first_name',
#        'full_name', 'birth_date', 'age', 'gender', 'country_of_citizenship',
#        'country_of_residence', 'city_of_residence', 'business_category',
#        'business_industries', 'organization_name', 'position_in_organization',
#        'self_made', 'wealth_status', 'birth_date_month', 'birth_date_year',
#        'birth_date_month_name', 'age-Cat'],
#       dtype='object')

# %%
from wordcloud import WordCloud, STOPWORDS
from collections import Counter

# %%
STOPWORDS.add('nan') # To ignore missing values
stop_words_list = list(STOPWORDS)
counts = Counter(df["business_category"].dropna().apply(lambda x:str(x)))
wcc = WordCloud(
    background_color="black",
    width=3000, height=1500,
    max_words=2000,
    stopwords=stop_words_list)
wcc.generate_from_frequencies(counts)

plt.figure(figsize=(10,5), facecolor='k')
plt.imshow(wcc,interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis("off")
plt.show()

# %%
STOPWORDS.add('nan') # To ignore missing values
stop_words_list = list(STOPWORDS)
counts = Counter(df["city_of_residence"].dropna().apply(lambda x:str(x)))
wcc = WordCloud(
    background_color="black",
    width=1600, height=800,
    max_words=2000,
    stopwords=stop_words_list)
wcc.generate_from_frequencies(counts)

plt.figure(figsize=(16,7), facecolor='k')
plt.imshow(wcc,interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis("off")
plt.show()

# %%
counts
# Out:
# Counter({'Entrepreneur': 561,
#          'Chairman': 510,
#          'Chairman and CEO': 447,
#          'Founder': 438,
#          'Investor': 415,
#          'CEO': 274,
#          'Cofounder': 136,
#          'President': 93,
#          'Owner': 87,
#          'Chief Executive Officer': 75,
#          'Founder and Chairman': 68,
#          'Director': 63,
#          'Investor, Philanthropist': 62,
#          'Founder and CEO': 56,
#          'Executive Chairman': 49,
#          'Philanthropist': 48,
#          'Cofounder and CEO': 41,
#          'Co-Chairman': 39,
#          'President and Chairman': 32,
#          'Co-Chief Executive Officer and Co-founder': 30,
#          'Former Chairman': 29,
#          'Partner': 28,
#          'Cofounder and Chairman': 27,
#          'Chairman Emeritus': 26,
#          'COO': 26,
#          'Chairman and Founder': 24,
#          'Founder, CEO': 23,
#          'Athlete': 22,
#          'Co-Founder': 21,
#          'Founder and Executive Chairman': 21,
#          'Entrepreneur, Investor': 21,
#          'Co-Chair': 20,
#          'CEO and Chairman': 20,
#          'Chairman & CEO': 19,
#          'Vice Chairman': 19,
#          'Cofounder, CEO': 18,
#          'Chair': 18,
#          'CEO and Founder': 17,
#          'Chairman, President & Chief Executive Officer': 16,
#          'Co-Chair and Co-CEO': 16,
#          'Co-Founder, Executive Vice President': 16,
#          'Founder & Co-Chief Investment Officer': 16,
#          'Vice Chairman and Director': 16,
#          'Cofounder and Chairman Emeritus': 16,
#          'President and Founder': 16,
#          'Co-founder, ex chairman of the board': 16,
#          'Chairman and Co-founder': 16,
#          'President and General Manager': 16,
#          'Director/Producer': 16,
#          'Entrepreneur, Personality': 16,
#          'Chairman Emeritus of the Board of Simon Property Group, Inc.': 15,
#          'Cofounder and Co-Chief Investment Officer': 15,
#          'Managing Member': 15,
#          'President and CEO': 14,
#          'Chief executive officer': 13,
#          'Board Member': 13,
#          'Founder & CEO': 13,
#          'Founder, Chairman and CEO': 12,
#          'Founder and Managing Director': 11,
#          'Honorary Chairman': 11,
#          'CEO of Artemis Group': 11,
#          'Founder, CEO and Chairman': 11,
#          'Founder & Owner': 10,
#          'Co-founder and CEO': 10,
#          'Non-Executive Chairman of the Board': 10,
#          'Cofounder-chair': 10,
#          'owner and ceo': 10,
#          'Dr.': 10,
#          'Cofounder, Chief Technology Officer and Chairman': 10,
#          'Owner, Fashion Designer': 9,
#          'Artist': 9,
#          'Chairman ': 9,
#          'CEO, Fashion Designer': 9,
#          'CEO and Cofounder': 9,
#          'President and Co-Founder': 8,
#          'Cofounder, Director Of Special Projects': 8,
#          'Chairman and co-CEO': 7,
#          'Managing Partner': 7,
#          'Executive Vice President': 7,
#          'Founder & Chairman': 7,
#          'Founder & President': 7,
#          'former Chairman and CEO': 7,
#          'president and CEO': 6,
#          'Founder and director emeritus': 6,
#          'Chief Yahoo (director)': 6,
#          'Chief Technology Officer and Chairman': 6,
#          'Cofounder & Chairman Emeritus': 6,
#          'Chief Product Officer and Chairman': 6,
#          'Chairman of Louis Dreyfus': 6,
#          'Founder-CEO': 6,
#          'Chairman of the Board': 6,
#          'Actor': 6,
#          'CTO and Founder': 6,
#          'Entrepreneur, Personality, Philanthropist': 6,
#          'Cofounder and board member': 6,
#          'Author': 5,
#          'Entrepreneur, Journalist': 5,
#          'Director and Member of Executive Committee': 4,
#          'President, Fidelity Personal, Workplace and Institutional Services': 4,
#          'Director/Producer, Investor': 4,
#          'Chairman, CEO and President': 4,
#          'Founder and Joint CEO': 4,
#          'chairman and CEO': 4,
#          'Chief Product Officer & Cofounder': 4,
#          'Executive chairman': 4,
#          'Senior Advisor': 4,
#          'CEO & President': 4,
#          'Former Chairman and CEO': 4,
#          'Co-Founder & CEO': 4,
#          'CEO & Founder ': 4,
#          'Founder & Co-Senior Managing Partner': 3,
#          'Cofounder, Chairman and CEO': 3,
#          'CEO, Chairman & Founder': 3,
#          'Mayor, New York City': 3,
#          'co-founder': 3,
#          'Chairman Emeritus ': 3,
#          'President of PE firm Florac': 3,
#          'CPO & Cofounder': 3,
#          'Founder-chair': 3,
#          'President-CEO': 3,
#          'Founder ': 3,
#          'Vice President and Cofounder': 3,
#          'Managing Director': 3,
#          'Cofounder-President': 3,
#          'Personality': 3,
#          'Cochair': 3,
#          'Musician': 3,
#          'Founder and Executive Co-Chairman': 2,
#          'Drug Trafficker': 2,
#          'Chairman & Founder': 2,
#          'Founder and Chief Executive Officer': 2,
#          'Cofounder & chairman': 2,
#          'CEO, Ant Financial Services': 2,
#          'Co-CEO': 2,
#          'Inventor': 2,
#          'Founder, Chair and Managing Director': 2,
#          'Cofounder/CEO': 2,
#          'Chairman and Cofounder': 2,
#          'Professor': 2,
#          'Cofounder & Chair of Airbnb.org': 2,
#          'Cofounder, Chief Development Officer and Chairman': 2,
#          'CEO, cofounder': 2,
#          'Cofounder & CEO': 2,
#          'Cofounder and Co-executive Chairman': 2,
#          'Chief Yahoo': 2,
#          'Advisor': 2,
#          'Cofounder and Director': 2,
#          'Chief Marketing Officer': 2,
#          'Founder and Chief Product Officer': 2,
#          'Co-founder': 1,
#          'President of the Management Board and Editorial Director': 1,
#          'President, Financial Services': 1,
#          'Cofounder and co-CEO': 1,
#          'Actress, Director/Producer, Entrepreneur, Personality, Philanthropist': 1,
#          'Director/Producer, Entrepreneur, Personality, Philanthropist': 1,
#          'Director Emeritus': 1,
#          'Founder and Chair': 1,
#          'Chief Technology Officer': 1,
#          'Chief Product Officer': 1,
#          'Author, Philanthropist': 1,
#          'Ant Group': 1,
#          'Cofounder(s)': 1,
#          'Global Managing Partner': 1,
#          'Executive Chairman ': 1})

# %%
STOPWORDS.add('nan') # To ignore missing values
stop_words_list = list(STOPWORDS)
counts = Counter(df["position_in_organization"].dropna().apply(lambda x:str(x)))
wcc = WordCloud(
    background_color="black",
    width=1600, height=800,
    max_words=2000,
    stopwords=stop_words_list)
wcc.generate_from_frequencies(counts)

plt.figure(figsize=(14,6), facecolor='k')
plt.imshow(wcc,interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Comparision between [2017 to 2023] data to [1997 to 2023] of missing values.

# %%
df_1997_2023 = pd.read_csv(r'artifacts/ForbesBillionaires-dataset/all_billionaires_1997_2023.csv')
df_2017_2023 = pd.read_csv(r'artifacts/ForbesBillionaires-dataset/all_billionaires_2017_2023.csv')

# %%
# plt.subplots(nrows=1,ncols=2,figsize = (12,6))
# plt.subplot(1,2,1)
msno.bar(df_1997_2023,figsize=(10,5),fontsize=10)
# plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
msno.bar(df_2017_2023,figsize=(10,5),fontsize=10)
# Out:
# <Axes: >

# %%
msno.dendrogram(df_2017_2023,figsize=(10,5),fontsize=10)
# Out:
# <Axes: >

# %%
df_1997_2023
# Out:
#        year  month    rank net_worth     last_name            first_name  \
# 0      1997      7     NaN     2.0 B  Sophonpanich                Chatri
# 1      1997      7     NaN     1.8 B     Adulyadej         King Bhumibol
# 2      1998      7     NaN     3.3 B         Safra                Edmond
# 3      1999      7     NaN     1.0 B       Hinduja  Srichand, Gopichand,
# 4      1999      7     NaN     7.1 B       Schwarz                Dieter
# ...     ...    ...     ...       ...           ...                   ...
# 31727  2023      4  2540.0     1.0 B            Yu                  Rong
# 31728  2023      4  2540.0     1.0 B     Yuengling               Richard
# 31729  2023      4  2540.0     1.0 B         Zhang               Gongyun
# 31730  2023      4  2540.0     1.0 B         Zhang               Guiping
# 31731  2023      4  2540.0     1.0 B         Zobel                 Inigo
#
#                           full_name  birth_date   age gender  \
# 0      Chatri Sophonpanich & family  1934-02-28  73.0   Male
# 1           King Bhumibol Adulyadej  1927-12-05  69.0   Male
# 2                      Edmond Safra  1932-08-06  65.0   Male
# 3      Srichand & Gopichand Hinduja  1935-11-28   NaN    NaN
# 4                    Dieter Schwarz  1939-09-24  59.0   Male
# ...                             ...         ...   ...    ...
# 31727                       Yu Rong  1971-12-14  51.0   Male
# 31728        Richard Yuengling, Jr.  1943-03-10  80.0   Male
# 31729                 Zhang Gongyun  1962-12-18  60.0   Male
# 31730        Zhang Guiping & family  1951-08-21  71.0   Male
# 31731                   Inigo Zobel  1956-11-01  66.0   Male
#
#       country_of_citizenship country_of_residence city_of_residence  \
# 0                   Thailand             Thailand           Bangkok
# 1                   Thailand                  NaN               NaN
# 2                    Lebanon              Lebanon               NaN
# 3                      India       United Kingdom            London
# 4                    Germany              Germany        Neckarsulm
# ...                      ...                  ...               ...
# 31727                  China                China          Shanghai
# 31728          United States        United States        Pottsville
# 31729                  China                China             Gaomi
# 31730                  China                China           Nanjing
# 31731            Philippines          Philippines            Makati
#
#              business_category          business_industries organization_name  \
# 0      Finance and Investments  ['Finance and Investments']               NaN
# 1                          NaN                          NaN               NaN
# 2                          NaN                          NaN               NaN
# 3                          NaN                          NaN               NaN
# 4             Fashion & Retail         ['Fashion & Retail']               NaN
# ...                        ...                          ...               ...
# 31727               Healthcare               ['Healthcare']               NaN
# 31728          Food & Beverage          ['Food & Beverage']               NaN
# 31729            Manufacturing            ['Manufacturing']               NaN
# 31730              Real Estate              ['Real Estate']               NaN
# 31731              Diversified              ['Diversified']               NaN
#
#       position_in_organization self_made     wealth_status
# 0                          NaN     False               NaN
# 1                          NaN     False               NaN
# 2                          NaN      True               NaN
# 3                          NaN     False               NaN
# 4                          NaN      True               NaN
# ...                        ...       ...               ...
# 31727                      NaN      True         Decreased
# 31728                      NaN     False     Remained Even
# 31729                      NaN      True  Returned to List
# 31730                      NaN      True         Decreased
# 31731                      NaN     False  Returned to List
#
# [31732 rows x 19 columns]

# %%
df_2017_2023['rank'].value_counts().count
# Out:
# <bound method Series.count of rank
# 1818    234
# 1513    166
# 2524    150
# 1929    147
# 2378    146
#        ...
# 125       2
# 131       2
# 134       2
# 255       1
# 168       1
# Name: count, Length: 606, dtype: int64>

# %%
sns.barplot(x=df_2017_2023['rank'].value_counts().index,y=df_2017_2023['rank'].value_counts().values)
# Out:
# <Axes: xlabel='rank'>

# %%
counts = df_2017_2023['rank'].value_counts()

plt.bar(counts.values, counts.index)
plt.xlabel('Rank')
plt.ylabel('Count')
plt.title('Rank Distribution')

plt.show()

# %%
counts = df_2017_2023['rank'].value_counts()

sns.barplot(y=counts.index, x=counts.values)

# sns.set(xlabel='Rank', ylabel='Count', title='Rank Value Counts')

sns.despine()
